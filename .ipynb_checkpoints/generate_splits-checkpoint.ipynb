# %%
import pandas as pd
import numpy as np
import re


df = pd.read_csv('mbti_1.csv')

# replace URLs

# replace MBTI
# https://stackoverflow.com/questions/16720541/python-string-replace-regular-expression/16720705
mbti_pat = r"ISFJ|ESFP|ISFP|ISTP|ENFP|ENFJ|INFJ|ESTP|ESFJ|ESTJ|ENTP|INFP|INTP|INTJ|ISTJ|ENTJ"
mbti_regex = re.compile(mbti_pat, re.IGNORECASE)
MBTI_REP = '$MBTI$'

# replace hashtags
hashtag_pat = r"(\#[a-zA-Z0-9]+\b)"
hashtag_regex = re.compile(hashtag_pat)
HASHTAG_REP = '$HASHTAG$'

# Replace links with $link$
# https://stackoverflow.com/questions/3809401/what-is-a-good-regular-expression-to-match-a-url
link_pat = r"(http(s)?:\/\/.)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)"
LINK_REP = '$LINK$'

df['posts'] = df['posts'].apply(lambda x: re.sub(mbti_pat, MBTI_REP, x))
df['posts'] = df['posts'].apply(lambda x: re.sub(hashtag_pat, HASHTAG_REP, x))
df['posts'] = df['posts'].apply(lambda x: re.sub(link_pat, LINK_REP, x))


df['posts'] = df['posts'].apply(lambda x: x.split('|||'))

# %%
df['IE'] = df['type'].apply(lambda x: 'I' if x[0] == 'I' else 'E')
df['NS'] = df['type'].apply(lambda x: 'N' if x[1] == 'N' else 'S')
df['FT'] = df['type'].apply(lambda x: 'F' if x[2] == 'F' else 'T')
df['PJ'] = df['type'].apply(lambda x: 'P' if x[3] == 'P' else 'J')

# %%
list(df.columns)
# Out:
# ['type', 'posts', 'IJ', 'NS', 'FT', 'PJ']

# %%
train, dev, test = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])

# %%
df_ie = df[['type', 'posts', 'IE']]
df_ns = df[['type', 'posts', 'NS']]
df_ft = df[['type', 'posts', 'FT']]
df_pj = df[['type', 'posts', 'PJ']]

# %%
train_ie, dev_ie, test_ie = np.split(df_ie.sample(frac=1), [int(.6*len(df_ie)), int(.8*len(df_ie))])
train_ns, dev_ns, test_ns = np.split(df_ns.sample(frac=1), [int(.6*len(df_ns)), int(.8*len(df_ns))])
train_ft, dev_ft, test_ft = np.split(df_ft.sample(frac=1), [int(.6*len(df_ft)), int(.8*len(df_ft))])
train_pj, dev_pj, test_pj = np.split(df_pj.sample(frac=1), [int(.6*len(df_pj)), int(.8*len(df_pj))])
# Out:
#       type                                              posts IE
# 0     INFJ  ['$LINK$, $LINK$, enfp and intj moments  $LINK...  I
# 1     ENTP  ['I'm finding the lack of me in these posts ve...  E
# 2     INTP  ['Good one  _____   $LINK$, Of course, to whic...  I
# 3     INTJ  ['Dear $MBTI$,   I enjoyed our conversation th...  I
# 4     ENTJ  ['You're fired., That's another silly misconce...  E
# 5     INTJ  ['18/37 @.@, Science  is not perfect. No scien...  I
# 6     INFJ  ['No, I can't draw on my own nails (haha). Tho...  I
# 7     INTJ  ['I tend to build up a collection of things on...  I
# 8     INFJ  [I'm not sure, that's a good question. The dis...  I
# 9     INTP  ['$LINK$, I'm in this position where I have to...  I
# 10    INFJ  ['One time my parents were fighting over my da...  I
# 11    ENFJ  ['$LINK$, 51 :o, I went through a break up som...  E
# 12    INFJ  ['Joe santagato - $MBTI$, $MBTI$ or  $MBTI$?  ...  I
# 13    INTJ  ['Fair enough, if that's how you want to look ...  I
# 14    INTP  ['Basically this...  $LINK$, Can I has Cheezbu...  I
# 15    INTP  ['Your comment screams $MBTI$, bro. Especially...  I
# 16    INFJ  ['some of these both excite and calm me:  BUTT...  I
# 17    INFP  ['I think we do agree. I personally don't cons...  I
# 18    INFJ  ['I fully believe in the power of being a prot...  I
# 19    INFP  ['That's normal, it happens also to me. If I a...  I
# 20    INTP  ['Steve Job's was recognized for his striving ...  I
# 21    INFJ  ['It is very annoying to be misinterpreted. Es...  I
# 22    ENTJ  ['Now I'm interested. But too lazy to go resea...  E
# 23    INFP  ['45016 urh sorry uh. couldn't resist., all of...  I
# 24    ENTJ  ['Still going strong at just over the two year...  E
# 25    INFP  ['Personally, I was thinking this would be mor...  I
# 26    ENFP  ['He doesn't want to go on the trip without me...  E
# 27    ISFP  ['They paint without numbers, I'd guess at ist...  I
# 28    INFP  ['Basically, my main questions are : What do y...  I
# 29    INFJ  ['I think that that can absolutely be true of ...  I
# ...    ...                                                ... ..
# 8645  INFJ  ['I play cello, and I'm also a classically tra...  I
# 8646  INFP  [Its more or less based on how YOU experienced...  I
# 8647  INTP  [Socionics picked up on this.  They call it vi...  I
# 8648  INFP  ['Good advice, thank you., I am in a tough sit...  I
# 8649  INFP  [$LINK$  enjoy infps, okok lets stop at kickin...  I
# 8650  INFJ  ['I think the real question is whether $MBTI$s...  I
# 8651  ISTP  ['-Being alone -Being insensitive  -Over think...  I
# 8652  ISFJ  ['Being assertive and standing up for myself i...  I
# 8653  INFP  ['You should do whatever it is you want. If yo...  I
# 8654  ISTJ  ['Assuming I had a hand in it, I always at lea...  I
# 8655  INFJ  ['I find that poster and your facial expressio...  I
# 8656  INFJ  [Rim  In some approximate order, it seems like...  I
# 8657  INTJ  [Social  1) Generally, I positively associate ...  I
# 8658  ESFJ  ['Don't worry, I do that too when a car comes ...  E
# 8659  ENFP  ['leoni I had really bad social anxiety until ...  E
# 8660  INFP  ['I love the vastness of the sky, because my p...  I
# 8661  ENTP  ['**haven't logged in and read posts for over ...  E
# 8662  INTJ  ['I can't say I have any one specific belief. ...  I
# 8663  INTP  ['doesn't matter, you don't have a choice, Ele...  I
# 8664  INTP  ['$LINK$, So many, but I'd say there's a tie b...  I
# 8665  ENTP  ['This test wasn't even close on my gender, ag...  E
# 8666  INTJ  ['Highly recommend this to those who wants to ...  I
# 8667  ENTP  ['I think generally people experience post tra...  E
# 8668  INTJ  ['Here's a planned stress relieving activity t...  I
# 8669  INFJ  ['I'm not sure about a method for picking out ...  I
# 8670  ISFP  ['$LINK$, IxFP just because I always think of ...  I
# 8671  ENFP  ['$LINK$ this thread already exists someplace ...  E
# 8672  INTP  ['So many questions when i do these things.  I...  I
# 8673  INFP  ['I am very conflicted right now when it comes...  I
# 8674  INFP  ['It has been too long since I have been on pe...  I
#
# [8675 rows x 3 columns]
