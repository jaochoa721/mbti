# %%
import pandas as pd
import numpy as np
import re


df = pd.read_csv('mbti_1.csv')

# replace URLs

# replace MBTI
# https://stackoverflow.com/questions/16720541/python-string-replace-regular-expression/16720705
mbti_pat = r"ISFJ|ESFP|ISFP|ISTP|ENFP|ENFJ|INFJ|ESTP|ESFJ|ESTJ|ENTP|INFP|INTP|INTJ|ISTJ|ENTJ"
mbti_regex = re.compile(mbti_pat, re.IGNORECASE)
MBTI_REP = '$MBTI$'

# replace hashtags
hashtag_pat = r"(\#[a-zA-Z0-9]+\b)"
hashtag_regex = re.compile(hashtag_pat)
HASHTAG_REP = '$HASHTAG$'

# Replace links with $link$
# https://stackoverflow.com/questions/3809401/what-is-a-good-regular-expression-to-match-a-url
link_pat = r"(http(s)?:\/\/.)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)"
LINK_REP = '$LINK$'

df['posts'] = df['posts'].apply(lambda x: re.sub(mbti_pat, MBTI_REP, x))
df['posts'] = df['posts'].apply(lambda x: re.sub(hashtag_pat, HASHTAG_REP, x))
df['posts'] = df['posts'].apply(lambda x: re.sub(link_pat, LINK_REP, x))


df['posts'] = df['posts'].apply(lambda x: x.split('|||'))

# %%
df['IJ'] = df['type'].apply(lambda x: 'I' if x[0] == 'I' else 'E')
df['NS'] = df['type'].apply(lambda x: 'N' if x[1] == 'N' else 'S')
df['FT'] = df['type'].apply(lambda x: 'F' if x[2] == 'F' else 'T')
df['PJ'] = df['type'].apply(lambda x: 'P' if x[3] == 'P' else 'J')

# %%
df
# Out:
#       type                                              posts IJ NS FT PJ
# 0     INFJ  ['$LINK$, $LINK$, enfp and intj moments  $LINK...  I  N  F  J
# 1     ENTP  ['I'm finding the lack of me in these posts ve...  E  N  T  P
# 2     INTP  ['Good one  _____   $LINK$, Of course, to whic...  I  N  T  P
# 3     INTJ  ['Dear $MBTI$,   I enjoyed our conversation th...  I  N  T  J
# 4     ENTJ  ['You're fired., That's another silly misconce...  E  N  T  J
# 5     INTJ  ['18/37 @.@, Science  is not perfect. No scien...  I  N  T  J
# 6     INFJ  ['No, I can't draw on my own nails (haha). Tho...  I  N  F  J
# 7     INTJ  ['I tend to build up a collection of things on...  I  N  T  J
# 8     INFJ  [I'm not sure, that's a good question. The dis...  I  N  F  J
# 9     INTP  ['$LINK$, I'm in this position where I have to...  I  N  T  P
# 10    INFJ  ['One time my parents were fighting over my da...  I  N  F  J
# 11    ENFJ  ['$LINK$, 51 :o, I went through a break up som...  E  N  F  J
# 12    INFJ  ['Joe santagato - $MBTI$, $MBTI$ or  $MBTI$?  ...  I  N  F  J
# 13    INTJ  ['Fair enough, if that's how you want to look ...  I  N  T  J
# 14    INTP  ['Basically this...  $LINK$, Can I has Cheezbu...  I  N  T  P
# 15    INTP  ['Your comment screams $MBTI$, bro. Especially...  I  N  T  P
# 16    INFJ  ['some of these both excite and calm me:  BUTT...  I  N  F  J
# 17    INFP  ['I think we do agree. I personally don't cons...  I  N  F  P
# 18    INFJ  ['I fully believe in the power of being a prot...  I  N  F  J
# 19    INFP  ['That's normal, it happens also to me. If I a...  I  N  F  P
# 20    INTP  ['Steve Job's was recognized for his striving ...  I  N  T  P
# 21    INFJ  ['It is very annoying to be misinterpreted. Es...  I  N  F  J
# 22    ENTJ  ['Now I'm interested. But too lazy to go resea...  E  N  T  J
# 23    INFP  ['45016 urh sorry uh. couldn't resist., all of...  I  N  F  P
# 24    ENTJ  ['Still going strong at just over the two year...  E  N  T  J
# 25    INFP  ['Personally, I was thinking this would be mor...  I  N  F  P
# 26    ENFP  ['He doesn't want to go on the trip without me...  E  N  F  P
# 27    ISFP  ['They paint without numbers, I'd guess at ist...  I  S  F  P
# 28    INFP  ['Basically, my main questions are : What do y...  I  N  F  P
# 29    INFJ  ['I think that that can absolutely be true of ...  I  N  F  J
# ...    ...                                                ... .. .. .. ..
# 8645  INFJ  ['I play cello, and I'm also a classically tra...  I  N  F  J
# 8646  INFP  [Its more or less based on how YOU experienced...  I  N  F  P
# 8647  INTP  [Socionics picked up on this.  They call it vi...  I  N  T  P
# 8648  INFP  ['Good advice, thank you., I am in a tough sit...  I  N  F  P
# 8649  INFP  [$LINK$  enjoy infps, okok lets stop at kickin...  I  N  F  P
# 8650  INFJ  ['I think the real question is whether $MBTI$s...  I  N  F  J
# 8651  ISTP  ['-Being alone -Being insensitive  -Over think...  I  S  T  P
# 8652  ISFJ  ['Being assertive and standing up for myself i...  I  S  F  J
# 8653  INFP  ['You should do whatever it is you want. If yo...  I  N  F  P
# 8654  ISTJ  ['Assuming I had a hand in it, I always at lea...  I  S  T  J
# 8655  INFJ  ['I find that poster and your facial expressio...  I  N  F  J
# 8656  INFJ  [Rim  In some approximate order, it seems like...  I  N  F  J
# 8657  INTJ  [Social  1) Generally, I positively associate ...  I  N  T  J
# 8658  ESFJ  ['Don't worry, I do that too when a car comes ...  E  S  F  J
# 8659  ENFP  ['leoni I had really bad social anxiety until ...  E  N  F  P
# 8660  INFP  ['I love the vastness of the sky, because my p...  I  N  F  P
# 8661  ENTP  ['**haven't logged in and read posts for over ...  E  N  T  P
# 8662  INTJ  ['I can't say I have any one specific belief. ...  I  N  T  J
# 8663  INTP  ['doesn't matter, you don't have a choice, Ele...  I  N  T  P
# 8664  INTP  ['$LINK$, So many, but I'd say there's a tie b...  I  N  T  P
# 8665  ENTP  ['This test wasn't even close on my gender, ag...  E  N  T  P
# 8666  INTJ  ['Highly recommend this to those who wants to ...  I  N  T  J
# 8667  ENTP  ['I think generally people experience post tra...  E  N  T  P
# 8668  INTJ  ['Here's a planned stress relieving activity t...  I  N  T  J
# 8669  INFJ  ['I'm not sure about a method for picking out ...  I  N  F  J
# 8670  ISFP  ['$LINK$, IxFP just because I always think of ...  I  S  F  P
# 8671  ENFP  ['$LINK$ this thread already exists someplace ...  E  N  F  P
# 8672  INTP  ['So many questions when i do these things.  I...  I  N  T  P
# 8673  INFP  ['I am very conflicted right now when it comes...  I  N  F  P
# 8674  INFP  ['It has been too long since I have been on pe...  I  N  F  P
#
# [8675 rows x 6 columns]
