# %%
import pandas as pd
import numpy as np
import re


df = pd.read_csv('mbti_1.csv')

# replace URLs

# replace MBTI
# https://stackoverflow.com/questions/16720541/python-string-replace-regular-expression/16720705
mbti_pat = r"ISFJ|ESFP|ISFP|ISTP|ENFP|ENFJ|INFJ|ESTP|ESFJ|ESTJ|ENTP|INFP|INTP|INTJ|ISTJ|ENTJ"
mbti_regex = re.compile(mbti_pat, re.IGNORECASE)
MBTI_REP = '$MBTI$'

# replace hashtags
hashtag_pat = r"(\#[a-zA-Z0-9]+\b)"
hashtag_regex = re.compile(hashtag_pat)
HASHTAG_REP = '$HASHTAG$'

# Replace links with $link$
# https://stackoverflow.com/questions/3809401/what-is-a-good-regular-expression-to-match-a-url
link_pat = r"(http(s)?:\/\/.)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)"
LINK_REP = '$LINK$'

df['posts'] = df['posts'].apply(lambda x: re.sub(mbti_pat, MBTI_REP, x))
df['posts'] = df['posts'].apply(lambda x: re.sub(hashtag_pat, HASHTAG_REP, x))
df['posts'] = df['posts'].apply(lambda x: re.sub(link_pat, LINK_REP, x))


df['posts'] = df['posts'].apply(lambda x: x.split('|||'))

# %%
df['IE'] = df['type'].apply(lambda x: 'I' if x[0] == 'I' else 'E')
df['NS'] = df['type'].apply(lambda x: 'N' if x[1] == 'N' else 'S')
df['FT'] = df['type'].apply(lambda x: 'F' if x[2] == 'F' else 'T')
df['PJ'] = df['type'].apply(lambda x: 'P' if x[3] == 'P' else 'J')

# %%
list(df.columns)
# Out:
# ['type', 'posts', 'IJ', 'NS', 'FT', 'PJ']

# %%
train, dev, test = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])

# %%
df_ie = df[['type', 'posts', 'IE']]
df_ns = df[['type', 'posts', 'NS']]
df_ft = df[['type', 'posts', 'FT']]
df_pj = df[['type', 'posts', 'PJ']]

# %%
train_ie, dev_ie, test_ie = np.split(df_ie.sample(frac=1), [int(.6*len(df_ie)), int(.8*len(df_ie))])
train_ns, dev_ns, test_ns = np.split(df_ns.sample(frac=1), [int(.6*len(df_ns)), int(.8*len(df_ns))])
train_ft, dev_ft, test_ft = np.split(df_ft.sample(frac=1), [int(.6*len(df_ft)), int(.8*len(df_ft))])
train_pj, dev_pj, test_pj = np.split(df_pj.sample(frac=1), [int(.6*len(df_pj)), int(.8*len(df_pj))])

# %%
train_ie
# Out:
#       type                                              posts IE
# 546   ESTJ  [this is such a catch 22 , I'm here! Although,...  E
# 5817  ESFP  ['Yes! I'm also like this. When somthing catch...  E
# 527   INTP  ['Greetings and welcome to PerC! Don't worry t...  I
# 2262  INFP  ['Is it possible for an $MBTI$, or an introver...  I
# 6372  ESFP  ['You're right. It was wrong of me to assume, ...  E
# 5102  INTJ  ['I love how I hadn't posted for months until ...  I
# 7364  ENFP  ['$MBTI$?   $LINK$, I'm going $MBTI$   $LINK$ ...  E
# 3248  INFP  ['Ugh, so sick of being sick and this is only ...  I
# 7175  INFJ  [I know 3 other $MBTI$'s and they all live clo...  I
# 4681  ISFP  ['I am a guy, and this post might not really o...  I
# 5298  INTJ  ['Um..When you say digital, do you mean 3d gra...  I
# 6454  INFP  ['Dearest Almighty Universe,  Seriously, wtf?!...  I
# 6184  INFP  ['hmmm, I would say that I would probably try ...  I
# 2280  INFJ  ['The similar jokes are due to the characters ...  I
# 3275  ISFP  ['$LINK$  Just listen..., $LINK$, $LINK$, $LIN...  I
# 7724  INTJ  ['You don't like colleges and Universities, or...  I
# 7294  ESTP  [haha! That's SO my $MBTI$ dad., Well we just ...  E
# 2308  INFJ  ['$LINK$, $LINK$, $LINK$, $LINK$, $LINK$, $LIN...  I
# 4740  INTP  ['Fi can depend strongly in different types; i...  I
# 5769  ENFP  ['It depends how they cheated. If it was just ...  E
# 4822  INFJ  ['Melancholy Plegmatic 0 Sanguine, 43 Melancho...  I
# 2172  INFJ  ['just not there?, Infp, myanonemail  Somethin...  I
# 628   INFP  ['Shortstacked and ready to gamble..., Why spe...  I
# 6940  INFP  ['So true!  I said earlier that my face was ve...  I
# 8235  INFP  ['Doctor Strange  Those action scenes with kal...  I
# 6641  INFJ  [I find users with Fi and Ti quite attractive....  I
# 7004  INFJ  ['Blessing $MBTI$   $LINK$, I'm not entirely s...  I
# 3376  ISFJ  [sorry it took me a while to read your post. I...  I
# 2837  ISTP  ['I don't deserve my mother, You know they're ...  I
# 6683  INFP  ['No, no, wait, it gets stranger. There's not ...  I
# ...    ...                                                ... ..
# 6920  INTP  ['Athletic physique with strong legs and core ...  I
# 6639  ENTJ  ['Good evening fellow $MBTI$s.  I wanted to te...  E
# 2019  INTJ  ['$LINK$  $LINK$, “Everywhere I go I find a po...  I
# 817   INFJ  ['I don't believe the beliefs are necessarily ...  I
# 5909  ENFP  ['Yes, the renaissance was great because peopl...  E
# 1996  INTJ  ['Irratinal process dom. Honestly he makes suc...  I
# 405   ENFP  ['But ok, just so that i'd have followed the t...  E
# 6994  INFP  ['picture of me now...74944, Thanks! :-), I al...  I
# 1166  ISTJ  ['Former leader of the UK Labour party; Michae...  I
# 5600  ENTP  ['See, this doesn't sound anything but sane an...  E
# 3310  INTJ  ['Ahahahahahahahahaha omg, If I wasn't at work...  I
# 6354  INTJ  ['Two problems:  -pasting text or inserting an...  I
# 7955  INTJ  ['This is a status that I posted on Facebook t...  I
# 2879  ESTJ  ['Yes, totally agree with all of these! I'd sa...  E
# 6771  ISTP  ['I had met this new person, he was nice to me...  I
# 413   INFJ  ['Hey there! Just wondering about your experie...  I
# 4030  INFP  ['...doubting whether did I choose the right c...  I
# 6933  ISFJ  ['This. Though I console myself that I'm usual...  I
# 8320  ENTP  ['Nah, I would say 8w9 sx/sp., He is a thinker...  E
# 1307  INFP  ['haha these are always so inaccurate! also an...  I
# 3941  INFJ  ['$MBTI$'s are chill at times.  I'd say they a...  I
# 1309  ENTP  ['Oh come on $HASHTAG$.. our cute little mouse...  E
# 4210  ENFP  [I'm so glad I figured that out! I definitely ...  E
# 5779  INTJ  ['That's the problem. You're trying to underst...  I
# 1008  INFJ  ['I don't think Yuri has inferior Se. $MBTI$s ...  I
# 5460  INFP  ['YouTube - Wayne Smith - Under Me Sleng Teng,...  I
# 2808  INFP  ['I read through some of these descriptors of ...  I
# 3462  INTJ  ['I thinks it's likely to be true, or close to...  I
# 4999  ENFJ  ['This., I feel the same way about my $MBTI$ b...  E
# 2957  INTP  ['I think she's probably 315. I know she's def...  I
#
# [5205 rows x 3 columns]
